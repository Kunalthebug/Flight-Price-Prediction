# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_excel('Data_Train.xlsx')
test_df=pd.read_excel('Test_set.xlsx')

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
train_df.shape,test_df.shape
# Out:
# ((10683, 11), (2671, 10))

# %%
train_df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
big_df=train_df.append(test_df,sort=False)

# %%
big_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2     DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3           CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4           BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                     ...      ...           ...      ...         ...
# 2666        CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667              CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668        DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669        DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670        DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#      Additional_Info    Price
# 0            No info   3897.0
# 1            No info   7662.0
# 2            No info  13882.0
# 3            No info   6218.0
# 4            No info  13302.0
# ...              ...      ...
# 2666         No info      NaN
# 2667         No info      NaN
# 2668         No info      NaN
# 2669         No info      NaN
# 2670         No info      NaN
#
# [13354 rows x 11 columns]

# %%
big_df.shape
# Out:
# (13354, 11)

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %%
big_df['Date']=big_df['Date_of_Journey'].str.split('/').str[0]
big_df['Month']=big_df['Date_of_Journey'].str.split('/').str[1]
big_df['Year']=big_df['Date_of_Journey'].str.split('/').str[2]

# %%
big_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# 3    05  2019
# 4    03  2019

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                object
# Month               object
# Year                object
# dtype: object

# %%
big_df['Date']=big_df['Date'].astype(int)
big_df['Year']=big_df['Year'].astype(int)
big_df['Month']=big_df['Month'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# dtype: object

# %%
big_df=big_df.drop(['Date_of_Journey'],axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Arrival_Time']=big_df['Arrival_Time'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Total_Stops'].isnull().sum()
# Out:
# 1

# %%
big_df['Total_Stops']=big_df['Total_Stops'].fillna('1 stop')

# %%
big_df['Total_Stops'].isnull().sum()
# Out:
# 0

# %%
big_df['Total_Stops']=big_df['Total_Stops'].replace('non-stop','0 stop')

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Total_Stops']=big_df['Total_Stops'].str.split(' ').str[0]

# %%
big_df['Total_Stops']=big_df['Total_Stops'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops          int32
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# dtype: object

# %%
 big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration  Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m            0         No info   3897.0    24      3
# 1        13:15   7h 25m            2         No info   7662.0     1      5
# 2        04:25      19h            2         No info  13882.0     9      6
# 3        23:30   5h 25m            1         No info   6218.0    12      5
# 4        21:35   4h 45m            1         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Arrival_Hour']=big_df['Arrival_Time'].str.split(':').str[0]
big_df['Arrival_Minute']=big_df['Arrival_Time'].str.split(':').str[1]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration  Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m            0         No info   3897.0    24      3
# 1        13:15   7h 25m            2         No info   7662.0     1      5
# 2        04:25      19h            2         No info  13882.0     9      6
# 3        23:30   5h 25m            1         No info   6218.0    12      5
# 4        21:35   4h 45m            1         No info  13302.0     1      3
#
#    Year Arrival_Hour Arrival_Minute
# 0  2019           01             10
# 1  2019           13             15
# 2  2019           04             25
# 3  2019           23             30
# 4  2019           21             35

# %%
big_df['Arrival_Hour']=big_df['Arrival_Hour'].astype(int)
big_df['Arrival_Minute']=big_df['Arrival_Minute'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops          int32
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# dtype: object

# %%
big_df=big_df.drop(['Arrival_Time'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Duration  Total_Stops Additional_Info    Price  Date  Month  Year  \
# 0      2h 50m            0         No info   3897.0    24      3  2019
# 1      7h 25m            2         No info   7662.0     1      5  2019
# 2         19h            2         No info  13882.0     9      6  2019
# 3      5h 25m            1         No info   6218.0    12      5  2019
# 4      4h 45m            1         No info  13302.0     1      3  2019
# ...       ...          ...             ...      ...   ...    ...   ...
# 2666  23h 55m            1         No info      NaN     6      6  2019
# 2667   2h 35m            0         No info      NaN    27      3  2019
# 2668   6h 35m            1         No info      NaN     6      3  2019
# 2669  15h 15m            1         No info      NaN     6      3  2019
# 2670  14h 20m            1         No info      NaN    15      6  2019
#
#       Arrival_Hour  Arrival_Minute
# 0                1              10
# 1               13              15
# 2                4              25
# 3               23              30
# 4               21              35
# ...            ...             ...
# 2666            20              25
# 2667            16              55
# 2668             4              25
# 2669            19              15
# 2670            19              15
#
# [13354 rows x 14 columns]

# %%
big_df['Dep_Hour']=big_df['Dep_Time'].str.split(':').str[0]
big_df['Dep_Minute']=big_df['Dep_Time'].str.split(':').str[1]

# %%
big_df['Dep_Hour']=big_df['Dep_Hour'].astype(int)
big_df['Dep_Minute']=big_df['Dep_Minute'].astype(int)

# %%
big_df=big_df.drop(['Dep_Time'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
#       Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 0               0         No info   3897.0    24      3  2019             1
# 1               2         No info   7662.0     1      5  2019            13
# 2               2         No info  13882.0     9      6  2019             4
# 3               1         No info   6218.0    12      5  2019            23
# 4               1         No info  13302.0     1      3  2019            21
# ...           ...             ...      ...   ...    ...   ...           ...
# 2666            1         No info      NaN     6      6  2019            20
# 2667            0         No info      NaN    27      3  2019            16
# 2668            1         No info      NaN     6      3  2019             4
# 2669            1         No info      NaN     6      3  2019            19
# 2670            1         No info      NaN    15      6  2019            19
#
#       Arrival_Minute  Dep_Hour  Dep_Minute
# 0                 10        22          20
# 1                 15         5          50
# 2                 25         9          25
# 3                 30        18           5
# 4                 35        16          50
# ...              ...       ...         ...
# 2666              25        20          30
# 2667              55        14          20
# 2668              25        21          50
# 2669              15         4           0
# 2670              15         4          55
#
# [13354 rows x 15 columns]

# %%
big_df['Route_1']=big_df['Route'].str.split('→ ').str[0]
big_df['Route_2']=big_df['Route'].str.split('→ ').str[1]
big_df['Route_3']=big_df['Route'].str.split('→ ').str[2]
big_df['Route_4']=big_df['Route'].str.split('→ ').str[3]
big_df['Route_5']=big_df['Route'].str.split('→ ').str[4]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 0            0         No info   3897.0    24      3  2019             1
# 1            2         No info   7662.0     1      5  2019            13
# 2            2         No info  13882.0     9      6  2019             4
# 3            1         No info   6218.0    12      5  2019            23
# 4            1         No info  13302.0     1      3  2019            21
#
#    Arrival_Minute  Dep_Hour  Dep_Minute Route_1 Route_2 Route_3 Route_4  \
# 0              10        22          20    BLR      DEL     NaN     NaN
# 1              15         5          50    CCU     IXR     BBI      BLR
# 2              25         9          25    DEL     LKO     BOM      COK
# 3              30        18           5    CCU     NAG      BLR     NaN
# 4              35        16          50    BLR     NAG      DEL     NaN
#
#   Route_5
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
big_df['Price'].fillna((big_df['Price'].mean()),inplace=True)

# %%
big_df['Route_1'].fillna("None",inplace=True)
big_df['Route_2'].fillna("None",inplace=True)
big_df['Route_3'].fillna("None",inplace=True)
big_df['Route_4'].fillna("None",inplace=True)
big_df['Route_5'].fillna("None",inplace=True)

# %%
big_df
# Out:
#                 Airline    Source Destination                  Route Duration  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR  23h 55m
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   2h 35m
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   6h 35m
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK  15h 15m
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK  14h 20m
#
#       Total_Stops Additional_Info         Price  Date  Month  Year  \
# 0               0         No info   3897.000000    24      3  2019
# 1               2         No info   7662.000000     1      5  2019
# 2               2         No info  13882.000000     9      6  2019
# 3               1         No info   6218.000000    12      5  2019
# 4               1         No info  13302.000000     1      3  2019
# ...           ...             ...           ...   ...    ...   ...
# 2666            1         No info   9087.064121     6      6  2019
# 2667            0         No info   9087.064121    27      3  2019
# 2668            1         No info   9087.064121     6      3  2019
# 2669            1         No info   9087.064121     6      3  2019
# 2670            1         No info   9087.064121    15      6  2019
#
#       Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute Route_1 Route_2  \
# 0                1              10        22          20    BLR      DEL
# 1               13              15         5          50    CCU     IXR
# 2                4              25         9          25    DEL     LKO
# 3               23              30        18           5    CCU     NAG
# 4               21              35        16          50    BLR     NAG
# ...            ...             ...       ...         ...     ...     ...
# 2666            20              25        20          30    CCU     DEL
# 2667            16              55        14          20    CCU      BLR
# 2668             4              25        21          50    DEL     BOM
# 2669            19              15         4           0    DEL     BOM
# 2670            19              15         4          55    DEL     BOM
#
#      Route_3 Route_4 Route_5
# 0       None    None    None
# 1       BBI      BLR    None
# 2       BOM      COK    None
# 3        BLR    None    None
# 4        DEL    None    None
# ...      ...     ...     ...
# 2666     BLR    None    None
# 2667    None    None    None
# 2668     COK    None    None
# 2669     COK    None    None
# 2670     COK    None    None
#
# [13354 rows x 20 columns]

# %%
big_df=big_df.drop(['Route'],axis=1)
big_df=big_df.drop(['Duration'],axis=1)

# %%
big_df
# Out:
#                 Airline    Source Destination  Total_Stops Additional_Info  \
# 0                IndiGo  Banglore   New Delhi            0         No info
# 1             Air India   Kolkata    Banglore            2         No info
# 2           Jet Airways     Delhi      Cochin            2         No info
# 3                IndiGo   Kolkata    Banglore            1         No info
# 4                IndiGo  Banglore   New Delhi            1         No info
# ...                 ...       ...         ...          ...             ...
# 2666          Air India   Kolkata    Banglore            1         No info
# 2667             IndiGo   Kolkata    Banglore            0         No info
# 2668        Jet Airways     Delhi      Cochin            1         No info
# 2669          Air India     Delhi      Cochin            1         No info
# 2670  Multiple carriers     Delhi      Cochin            1         No info
#
#              Price  Date  Month  Year  Arrival_Hour  Arrival_Minute  Dep_Hour  \
# 0      3897.000000    24      3  2019             1              10        22
# 1      7662.000000     1      5  2019            13              15         5
# 2     13882.000000     9      6  2019             4              25         9
# 3      6218.000000    12      5  2019            23              30        18
# 4     13302.000000     1      3  2019            21              35        16
# ...            ...   ...    ...   ...           ...             ...       ...
# 2666   9087.064121     6      6  2019            20              25        20
# 2667   9087.064121    27      3  2019            16              55        14
# 2668   9087.064121     6      3  2019             4              25        21
# 2669   9087.064121     6      3  2019            19              15         4
# 2670   9087.064121    15      6  2019            19              15         4
#
#       Dep_Minute Route_1 Route_2 Route_3 Route_4 Route_5
# 0             20    BLR      DEL    None    None    None
# 1             50    CCU     IXR     BBI      BLR    None
# 2             25    DEL     LKO     BOM      COK    None
# 3              5    CCU     NAG      BLR    None    None
# 4             50    BLR     NAG      DEL    None    None
# ...          ...     ...     ...     ...     ...     ...
# 2666          30    CCU     DEL      BLR    None    None
# 2667          20    CCU      BLR    None    None    None
# 2668          50    DEL     BOM      COK    None    None
# 2669           0    DEL     BOM      COK    None    None
# 2670          55    DEL     BOM      COK    None    None
#
# [13354 rows x 18 columns]

# %%
big_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arrival_Hour       0
# Arrival_Minute     0
# Dep_Hour           0
# Dep_Minute         0
# Route_1            0
# Route_2            0
# Route_3            0
# Route_4            0
# Route_5            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
big_df['Airline']=encoder.fit_transform(big_df['Airline'])
big_df['Source']=encoder.fit_transform(big_df['Source'])
big_df['Destination']=encoder.fit_transform(big_df['Destination'])
big_df['Additional_Info']=encoder.fit_transform(big_df['Additional_Info'])
big_df['Route_1']=encoder.fit_transform(big_df['Route_1'])
big_df['Route_2']=encoder.fit_transform(big_df['Route_2'])
big_df['Route_3']=encoder.fit_transform(big_df['Route_3'])
big_df['Route_4']=encoder.fit_transform(big_df['Route_4'])
big_df['Route_5']=encoder.fit_transform(big_df['Route_5'])

# %%
big_df
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info  \
# 0           3       0            5            0                8
# 1           1       3            0            2                8
# 2           4       2            1            2                8
# 3           3       3            0            1                8
# 4           3       0            5            1                8
# ...       ...     ...          ...          ...              ...
# 2666        1       3            0            1                8
# 2667        3       3            0            0                8
# 2668        4       2            1            1                8
# 2669        1       2            1            1                8
# 2670        6       2            1            1                8
#
#              Price  Date  Month  Year  Arrival_Hour  Arrival_Minute  Dep_Hour  \
# 0      3897.000000    24      3  2019             1              10        22
# 1      7662.000000     1      5  2019            13              15         5
# 2     13882.000000     9      6  2019             4              25         9
# 3      6218.000000    12      5  2019            23              30        18
# 4     13302.000000     1      3  2019            21              35        16
# ...            ...   ...    ...   ...           ...             ...       ...
# 2666   9087.064121     6      6  2019            20              25        20
# 2667   9087.064121    27      3  2019            16              55        14
# 2668   9087.064121     6      3  2019             4              25        21
# 2669   9087.064121     6      3  2019            19              15         4
# 2670   9087.064121    15      6  2019            19              15         4
#
#       Dep_Minute  Route_1  Route_2  Route_3  Route_4  Route_5
# 0             20        0       13       24       12        4
# 1             50        2       25        1        3        4
# 2             25        3       32        4        5        4
# 3              5        2       34        3       12        4
# 4             50        0       34        8       12        4
# ...          ...      ...      ...      ...      ...      ...
# 2666          30        2       14        3       12        4
# 2667          20        2        5       24       12        4
# 2668          50        3        7        6       12        4
# 2669           0        3        7        6       12        4
# 2670          55        3        7        6       12        4
#
# [13354 rows x 18 columns]

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
df_train=big_df[0:10683]
df_test=big_df[10683:]

# %%
X=df_train.drop(['Price'],axis=1)
y=df_train.Price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
model=SelectFromModel(Lasso(alpha=0.005,random_state=0))

# %%
model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
selected_features=X_train.columns[(model.get_support())]

# %%
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Date', 'Month', 'Arrival_Hour', 'Arrival_Minute', 'Dep_Hour',
#        'Dep_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4', 'Route_5'],
#       dtype='object')

# %%
X_train=X_train.drop(['Year'],axis=1)

# %%
X_test=X_test.drop(['Year'],axis=1)

# %% [markdown]
# # Random Forest Resgessor

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 50 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 50, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.6s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.5s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.5s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.7s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.7s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   3.5s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   3.4s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   3.5s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   3.5s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=20, total=   3.5s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   1.1s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   1.1s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   1.1s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   1.1s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   1.1s
# [CV] n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.7s
# [CV] n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.6s
# [CV] n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.8s
# [CV] n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.9s
# [CV] n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=20, total=   9.0s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.8s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.7s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.7s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   5.0s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=15, total=   4.5s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   3.8s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   4.3s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   4.1s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   4.1s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   4.0s
# [CV] n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.0s
# [CV] n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.2s
# [CV] n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   1.1s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   6.6s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   6.8s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   6.6s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   6.3s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   6.5s
# [CV] n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   5.8s
# [CV] n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   5.5s
# [CV] n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   5.5s
# [CV] n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   5.8s
# [CV] n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   5.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   0.7s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   0.7s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   0.7s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   0.7s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   0.6s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   1.9s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   2.0s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   2.2s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   2.2s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   2.0s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   2.8s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   3.0s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   3.2s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   2.8s
# [CV] n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   3.1s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   3.7s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   3.8s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   3.9s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.4s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.3s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.5s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.5s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.4s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.1s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10, total=  11.7s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10, total=  10.5s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10, total=  10.4s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10, total=  10.0s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=10, total=   9.8s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=  10.0s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=   9.8s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=  11.6s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=  10.3s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=10, max_features=auto, max_depth=5, total=  10.5s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   3.0s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   3.1s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.9s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.9s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.9s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   5.7s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   5.0s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   5.6s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   6.1s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=   5.1s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   2.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   2.2s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   2.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   2.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=   2.3s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   7.3s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   7.3s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   7.3s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   7.4s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   7.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   7.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   7.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   7.2s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   7.4s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   7.3s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   6.7s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   6.6s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   6.6s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   6.6s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   6.6s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.9s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.8s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.8s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.8s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.9s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  10.2s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  10.3s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  10.6s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  11.5s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  14.3s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25, total=  29.6s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25, total=  30.7s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25, total=  26.9s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25, total=  25.2s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=25, total=  23.4s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   3.9s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   3.9s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   4.0s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   3.9s
# [CV] n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=15, total=   3.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   1.0s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   3.8s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   4.2s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   3.8s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   3.7s
# [CV] n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=700, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   3.7s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.1s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, total=   8.7s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   5.7s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   5.8s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   5.7s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   5.8s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   5.8s
# [CV] n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30, total=  19.7s
# [CV] n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30, total=  19.5s
# [CV] n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30, total=  20.1s
# [CV] n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30, total=  19.7s
# [CV] n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=15, min_samples_leaf=5, max_features=auto, max_depth=30, total=  19.6s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25, total=  16.5s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25, total=  16.5s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25, total=  16.6s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25, total=  16.5s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=25, total=  15.3s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.0s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=   5.4s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=   5.1s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=   4.9s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=   4.8s
# [CV] n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=   4.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5, total=   3.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5, total=   3.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5, total=   4.7s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5, total=   5.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=5, total=   4.6s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   4.4s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   4.5s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   4.3s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   4.3s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=25, total=   4.4s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   8.6s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   9.3s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   8.1s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   8.2s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=   8.2s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.9s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.3s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.8s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.9s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.8s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, total=  13.9s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, total=  14.2s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, total=  20.1s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, total=  15.1s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, total=  13.8s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15, total=   1.3s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15, total=   1.2s
# [CV] n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=15, total=   1.6s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   3.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   3.6s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   3.6s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   3.7s
# [CV] n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=   3.7s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.1s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   1.0s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.3s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.2s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.1s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   2.3s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   2.3s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   2.5s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   2.3s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=sqrt, max_depth=20, total=   2.3s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   3.0s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   3.0s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   3.2s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   3.1s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.9s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.9s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.1s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   4.0s
# [CV] n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=900, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   3.9s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.3s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.4s
# [CV] n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   1.4s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed: 22.8min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=50, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
y_pred=rf_random.predict(X_test)

# %%
import seaborn as sns

sns.distplot(y_test-y_pred)

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 606.7323489743551
# MSE: 1531026.414852511
# RMSE: 1237.3465217361347

# %%
import pickle
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# %%
Xreg=xgb.XGBRegressor()
Xreg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Various learning rate parameters
learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
#Subssample parameter values
subsample=[0.7,0.6,0.8]
# Minimum child weight parameters
min_child_weight=[3,4,5,6,7]

# %%
random_grid = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'subsample': subsample,
               'min_child_weight': min_child_weight}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'learning_rate': ['0.05', '0.1', '0.2', '0.3', '0.5', '0.6'], 'max_depth': [5, 10, 15, 20, 25, 30], 'subsample': [0.7, 0.6, 0.8], 'min_child_weight': [3, 4, 5, 6, 7]}

# %%
regressor=xgb.XGBRegressor()

# %%
xg_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
xg_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3, total=  11.1s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.0s remaining:    0.0s
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3, total=  10.7s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3, total=  10.7s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3, total=  11.0s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=6, max_depth=10, learning_rate=0.3, total=  11.9s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3, total=  10.8s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3, total=  11.0s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3, total=  10.6s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3, total=  10.9s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.3, total=  10.8s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   5.8s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   5.6s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   5.4s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   7.4s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   6.5s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05, total=  10.8s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05, total=  10.8s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05, total=  10.6s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05, total=   9.5s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=7, max_depth=10, learning_rate=0.05, total=   9.4s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   1.0s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   1.0s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   1.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   1.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   1.2s
# [CV] subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3, total=   2.8s
# [CV] subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3, total=   3.2s
# [CV] subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3, total=   3.6s
# [CV] subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3, total=   3.3s
# [CV] subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=500, min_child_weight=6, max_depth=5, learning_rate=0.3, total=   3.2s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2, total=   2.1s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2, total=   2.0s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2, total=   2.1s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2, total=   2.0s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=25, learning_rate=0.2, total=   2.0s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   8.9s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1, total=  10.7s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1, total=  11.2s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1, total=  10.9s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.1, total=  10.1s
# [CV] subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3, total=   7.1s
# [CV] subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3, total=   7.1s
# [CV] subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3, total=   7.0s
# [CV] subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3, total=   7.3s
# [CV] subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=500, min_child_weight=6, max_depth=15, learning_rate=0.3, total=   8.5s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2, total=   4.7s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2, total=   5.2s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2, total=   6.5s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2, total=   6.3s
# [CV] subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=1000, min_child_weight=5, max_depth=5, learning_rate=0.2, total=   6.4s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3, total=  16.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3, total=  12.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3, total=  13.4s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3, total=  12.8s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=5, max_depth=15, learning_rate=0.3, total=  14.0s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   3.7s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   5.9s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   5.3s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   4.8s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   4.8s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05, total=  14.9s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05, total=  14.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05, total=  19.4s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05, total=  16.9s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=3, max_depth=15, learning_rate=0.05, total=  16.4s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05, total=  23.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05, total=  24.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05, total=  21.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05, total=  23.2s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=4, max_depth=30, learning_rate=0.05, total=  21.8s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  23.1s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  24.9s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  24.4s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  32.9s
# [CV] subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=1100, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  34.0s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  23.2s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  22.3s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  23.6s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  20.9s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  21.5s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  11.6s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  11.4s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  14.0s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  16.7s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  12.5s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3, total=  17.1s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3, total=  22.6s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3, total=  13.0s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3, total=  14.3s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=4, max_depth=30, learning_rate=0.3, total=  15.1s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   6.8s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   6.4s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   6.2s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   6.4s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=3, max_depth=10, learning_rate=0.3, total=   5.0s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5, total=   6.7s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5, total=   6.5s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5, total=   7.2s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5, total=   6.6s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=30, learning_rate=0.5, total=   5.5s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  15.3s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  15.4s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  17.6s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  19.0s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=7, max_depth=30, learning_rate=0.5, total=  16.6s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  26.8s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  22.8s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  31.2s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  29.4s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  33.4s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  15.0s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  17.1s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  15.8s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  12.7s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  13.1s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1, total=  22.0s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1, total=  19.0s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1, total=  19.8s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1, total=  25.1s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=3, max_depth=30, learning_rate=0.1, total=  23.5s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5, total=   9.0s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5, total=   9.1s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5, total=  10.9s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5, total=  10.6s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=4, max_depth=30, learning_rate=0.5, total=  10.5s
# [CV] subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1, total=   7.8s
# [CV] subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1, total=   8.0s
# [CV] subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1, total=  11.5s
# [CV] subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1, total=  11.2s
# [CV] subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=300, min_child_weight=4, max_depth=30, learning_rate=0.1, total=   9.2s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3, total=   6.4s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3, total=   6.0s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3, total=   7.9s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3, total=   7.2s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=20, learning_rate=0.3, total=   5.6s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3, total=  41.9s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3, total=  39.8s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3, total=  36.7s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3, total=  30.6s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=30, learning_rate=0.3, total=  34.4s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1, total=   6.7s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1, total=   6.4s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1, total=   7.0s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1, total=   6.9s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=5, learning_rate=0.1, total=   6.8s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5, total=   2.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5, total=   2.2s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5, total=   2.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5, total=   2.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=6, max_depth=20, learning_rate=0.5, total=   2.1s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6, total=  18.0s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6, total=  15.5s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6, total=  17.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6, total=  18.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.6, total=  17.4s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   2.2s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   1.9s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   1.8s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   1.9s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   1.9s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   3.9s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   3.4s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   4.0s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   3.5s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=7, max_depth=30, learning_rate=0.05, total=   3.9s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1, total=   6.8s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1, total=   7.9s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1, total=   7.3s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1, total=   8.6s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=6, max_depth=5, learning_rate=0.1, total=   7.5s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05, total=   2.0s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05, total=   2.7s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05, total=   1.7s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05, total=   1.8s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.05, total=   1.8s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  19.1s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  20.3s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  19.1s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  22.6s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  19.0s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   2.7s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   3.7s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   3.4s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   2.7s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   2.8s
# [CV] subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3, total=  19.6s
# [CV] subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3, total=  18.8s
# [CV] subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3, total=  21.0s
# [CV] subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3, total=  19.8s
# [CV] subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=900, min_child_weight=7, max_depth=15, learning_rate=0.3, total=  18.4s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3, total=   2.0s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3, total=   2.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3, total=   1.9s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3, total=   2.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=5, max_depth=5, learning_rate=0.3, total=   2.7s
# [CV] subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6, total=  13.6s
# [CV] subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6, total=   9.8s
# [CV] subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6, total=  10.8s
# [CV] subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6, total=  10.3s
# [CV] subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.7, n_estimators=900, min_child_weight=7, max_depth=10, learning_rate=0.6, total=   9.3s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3, total=  10.1s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3, total=  10.5s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3, total=  11.2s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3, total=  11.2s
# [CV] subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=500, min_child_weight=7, max_depth=20, learning_rate=0.3, total=  11.5s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   6.0s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   5.8s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   5.4s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   5.4s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   5.5s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05, total=   6.2s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05, total=   6.3s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05, total=   6.2s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05, total=   6.3s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.05, total=   6.3s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05, total=  32.9s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05, total=  29.2s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05, total=  31.4s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05, total=  32.1s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=3, max_depth=30, learning_rate=0.05, total=  31.1s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2, total=  28.1s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2, total=  28.5s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2, total=  28.7s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2, total=  31.5s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=5, max_depth=30, learning_rate=0.2, total=  28.2s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  13.4s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  12.7s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  15.3s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  24.2s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=10, learning_rate=0.2, total=  18.4s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6, total=  10.8s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6, total=  11.0s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6, total=  11.0s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6, total=  10.6s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=10, learning_rate=0.6, total=  10.6s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=  23.7s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=  28.5s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=  27.1s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=  23.6s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=  23.3s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=7, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=7, max_depth=10, learning_rate=0.05, total=   7.4s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=7, max_depth=10, learning_rate=0.05
# ...
# [CV] subsample=0.8, n_estimators=800, min_child_weight=5, max_depth=20, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=5, max_depth=20, learning_rate=0.2, total=  25.9s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=5, max_depth=20, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=5, max_depth=20, learning_rate=0.2, total=  23.5s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3, total=   0.8s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3, total=   0.9s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3, total=   0.7s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3, total=   0.8s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=4, max_depth=5, learning_rate=0.3, total=   0.8s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5, total=  26.2s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5, total=  20.9s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5, total=  20.8s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5, total=  21.2s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=3, max_depth=20, learning_rate=0.5, total=  21.4s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5, total=   5.5s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5, total=   5.5s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5, total=   5.5s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5, total=   5.5s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=6, max_depth=5, learning_rate=0.5, total=   5.5s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   0.6s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   0.7s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   0.7s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   0.7s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.6, total=   0.7s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2, total=   2.2s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2, total=   3.0s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2, total=   2.9s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2, total=   2.9s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.2, total=   2.5s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  21.6s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  21.9s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  22.3s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  21.1s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=7, max_depth=15, learning_rate=0.1, total=  21.4s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2, total=   5.5s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2, total=   5.6s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2, total=   5.7s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2, total=   5.5s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.2, total=   5.4s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  10.3s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  10.2s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  10.4s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  10.3s
# [CV] subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3
# [CV]  subsample=0.7, n_estimators=400, min_child_weight=5, max_depth=25, learning_rate=0.3, total=  10.3s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1, total=  13.1s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1, total=  13.0s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1, total=  13.5s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1, total=  13.0s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=4, max_depth=10, learning_rate=0.1, total=  13.1s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5, total=  12.7s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5, total=  12.8s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5, total=  14.0s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5, total=  12.9s
# [CV] subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5
# [CV]  subsample=0.6, n_estimators=600, min_child_weight=6, max_depth=20, learning_rate=0.5, total=  12.8s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2, total=  19.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2, total=  27.4s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2, total=  22.2s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2, total=  32.7s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.2, total=  29.4s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1, total=  34.9s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1, total=  30.5s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1, total=  32.3s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1, total=  29.1s
# [CV] subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1
# [CV]  subsample=0.7, n_estimators=1200, min_child_weight=4, max_depth=15, learning_rate=0.1, total=  23.2s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  10.4s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6, total=  10.5s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6, total=   9.9s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6, total=   9.6s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=3, max_depth=20, learning_rate=0.6, total=   9.6s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   8.0s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   8.0s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   7.9s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   7.9s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   7.7s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed: 100.0min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_...
#                    param_distributions={'learning_rate': ['0.05', '0.1', '0.2',
#                                                           '0.3', '0.5', '0.6'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'min_child_weight': [3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200],
#                                         'subsample': [0.7, 0.6, 0.8]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
xg_random.best_params_
# Out:
# {'subsample': 0.8,
#  'n_estimators': 200,
#  'min_child_weight': 7,
#  'max_depth': 30,
#  'learning_rate': '0.05'}

# %%
xg_random.best_score_
# Out:
# -2706610.5360948807

# %%
predictions=xg_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 581.8129364061281
# MSE: 1371399.4515552593
# RMSE: 1171.0676545594022

# %%
file = open('XGBoost.pkl', 'wb')

# dump information to that file
pickle.dump(xg_random, file)
